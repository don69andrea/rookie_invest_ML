# %% [markdown]
# # Notebook 01: Data Collection & Feature Pipeline
#
# Dieses Notebook ist eine **Dokumentations- und Navigationshilfe**. Die eigentliche Pipeline liegt in den Skripten unter `src/`.
#
# ## F1 Pipeline (Kaggle Schema)
# - `src/f1/prep/ingest.py`
# - `src/f1/prep/clean.py`
# - `src/f1/build/build_features.py`
#
# ## F2 Pipeline (FIA Ergebnisse)
# - `src/f2/prep/ingest_fia.py`
# - `src/f2/prep/clean_f2_results.py`
# - `src/f2/prep/clean_name.py`
# - `src/f2/build/build_features.py`
#
# ## F3 Pipeline
# - `src/f3/build/build_race_features.py` (Race Features)
# - `src/f3/build/build_features.py` (Basic Season)
# - `src/f3/analysis/build_features_advanced.py` (Advanced Season)
#
# ## Serien-Merge
# - `src/all_series/build_all_master_features.py`
# - `src/all_series/build_all_master_features_core.py`
#
# ## Knowledge Base Demo
# - `src/demo/run_kb_demo.py`
